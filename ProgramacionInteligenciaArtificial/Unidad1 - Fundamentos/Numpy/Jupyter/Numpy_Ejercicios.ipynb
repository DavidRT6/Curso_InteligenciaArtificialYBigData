# %% [markdown]
# # Ejercicios NumPy

# %% [markdown]
# ---
# ## Para empezar...

# %% [markdown]
# Antes de empezar a trabajar de verdad, tendrás que importar la librería de NumPy:

# %%
import numpy as np

# %% [markdown]
# ---
# ## Ejercicio 1

# %% [markdown]
# Crea una array bidimensional, de tamaño 10x10, con valores de tipo float32 aleatorios entre 0 y 10, redondeados a 2 decimales. Luego, muestra las dimensiones, el tamaño y la forma que tiene mediante las propiedades correspondientes. Finalmente, calcula la suma de todos los valores, la media, obtén el valor máximo y el mínimo.

# %%
array = (np.random.rand(10, 10) * 10).astype(np.float32)
array = np.round(array, 2)
# Otra manera
# array = np.round(array, decimals=2)
print(f"{array}\n")

print(f"Dimensiones: {array.ndim}")
print(f"Tamaño: {array.size}")
print(f"Forma: {array.shape}")

print(f"Suma total: {np.sum(array)}")
print(f"Media: {np.mean(array)}")
print(f"Valor máximo: {np.max(array)}")
print(f"Valor mínimo: {np.min(array)}")

# Otra manera
# print(f"Suma total: {array.sum()}")
# print(f"Media: {array.mean()}")
# print(f"Valor máximo: {array.max()}")
# print(f"Valor mínimo: {array.min()}")
# Out:
# [[2.74 9.14 7.23 3.07 2.12 9.03 0.11 8.29 0.19 0.91]
#  [0.99 2.27 4.1  1.01 5.35 1.3  1.89 5.69 3.97 5.9 ]
#  [4.81 0.2  8.54 8.   6.99 8.54 7.71 0.86 3.37 9.84]
#  [2.61 2.41 2.68 4.38 2.98 2.8  5.38 9.05 4.09 5.82]
#  [5.73 2.46 6.5  1.04 2.26 5.65 1.7  9.92 2.3  0.29]
#  [8.06 7.22 4.38 8.49 8.91 6.99 1.37 6.6  1.65 4.52]
#  [0.33 8.07 7.01 6.89 1.77 3.36 8.73 8.81 0.15 4.35]
#  [4.99 4.38 7.64 3.88 0.95 2.1  2.98 3.72 8.4  1.03]
#  [3.8  7.82 0.85 1.52 0.42 4.12 7.69 0.49 3.34 3.66]
#  [9.14 2.94 3.58 2.49 5.26 8.42 4.94 4.06 0.76 7.07]]
#
# Dimensiones: 2
# Tamaño: 100
# Forma: (10, 10)
# Suma total: 444.30999755859375
# Media: 4.4430999755859375
# Valor máximo: 9.920000076293945
# Valor mínimo: 0.10999999940395355

# %% [markdown]
# ---
# ## Ejercicio 2

# %% [markdown]
# Crea un array de una dimensión de tipo int8. En una de las posiciones pon el valor 1000. ¿Qué ocurre y porqué?

# %%
array = np.array([1, 6, 1000, 4], dtype=np.int8)
print(array)

# %% [markdown]
# A continuación ejecuta alguna solución para este problema, ¿que harías?

# %%
array = np.array([1, 6, 1000, 4], dtype=np.int16)
print(array)

# %% [markdown]
# ---
# ## Ejercicio 3

# %% [markdown]
# Crea un array con 20 valores entre los números 1 y 2. Estos valores deben estar distribuídos de manera equitativa:

# %%
array = np.linspace(1, 2, 20)
print(array)
# Out:
# [1.         1.05263158 1.10526316 1.15789474 1.21052632 1.26315789
#  1.31578947 1.36842105 1.42105263 1.47368421 1.52631579 1.57894737
#  1.63157895 1.68421053 1.73684211 1.78947368 1.84210526 1.89473684
#  1.94736842 2.        ]

# %% [markdown]
# ---
# ## Ejercicio 4

# %% [markdown]
# Crea una matriz de forma 2x3 y muéstrala por pantalla. A continuación cambia su forma a una matriz 3x2. Luego obtén el resultado de multiplicar la primera por la segunda.

# %%
array1 = np.reshape(np.array([1, 2, 3, 4, 5, 6]), (2, 3))
# También se podría hacer así:
# array1 = np.array([1, 2, 3, 4, 5, 6])
# array2 = np.reshape(array1, (2, 3))
# print(array2)
array2 = np.reshape(array1, (3, 2))
resultado = np.dot(array1, array2)
print(array1)
print(array2)
print("Resultado:")
print(resultado)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 2]
#  [3 4]
#  [5 6]]
# Resultado:
# [[22 28]
#  [49 64]]

# %% [markdown]
# ---
# ## Ejercicio 5

# %% [markdown]
# Crea un array de 6x6 con números enteros aleatorios entre 0 y 10, luego realiza las siguientes operaciones:
# * Extrae la submatriz formada por las dos primeras filas y las tres primeras columnas.
# * Selecciona todas las filas, pero solo las columnas desde la 2ª hasta la 4ª.
# * Reemplaza todos los elementos en las tres primeras filas y tres primeras columnas con el valor 0.
# * Selecciona los elementos de las dos últimas filas que son mayores a 3

# %%
array = np.random.rand(6, 6) * 10
array = np.round(array, 2)
print(array)

print("------------------------")
array1 = array[:2, :3]
print(array1)

print("------------------------")
array2 = array[:, 1:4]
print(array2)

print("------------------------")
array3 = array
array3[:3, :3] = 0
print(array3)

print("------------------------")
ultimasFilas = array[-2:, :]
array4 = ultimasFilas[ultimasFilas > 3]
# Otra manera para hacerlo en una línea
# prueba = array[-2:, :][array[-2:, :]>3]
print(array4)
# Out:
# [[8.07 6.36 7.12 8.17 0.87 8.06]
#  [6.37 0.77 1.33 4.82 3.42 0.34]
#  [5.29 9.3  6.66 1.04 6.92 1.95]
#  [6.61 2.47 3.09 1.06 9.07 0.26]
#  [4.79 0.44 6.25 1.45 3.76 7.4 ]
#  [9.05 1.89 1.75 2.39 8.32 8.7 ]]
# ------------------------
# [[8.07 6.36 7.12]
#  [6.37 0.77 1.33]]
# ------------------------
# [[6.36 7.12 8.17]
#  [0.77 1.33 4.82]
#  [9.3  6.66 1.04]
#  [2.47 3.09 1.06]
#  [0.44 6.25 1.45]
#  [1.89 1.75 2.39]]
# ------------------------
# [[0.   0.   0.   8.17 0.87 8.06]
#  [0.   0.   0.   4.82 3.42 0.34]
#  [0.   0.   0.   1.04 6.92 1.95]
#  [6.61 2.47 3.09 1.06 9.07 0.26]
#  [4.79 0.44 6.25 1.45 3.76 7.4 ]
#  [9.05 1.89 1.75 2.39 8.32 8.7 ]]
# ------------------------
# [4.79 6.25 3.76 7.4  9.05 8.32 8.7 ]

# %% [markdown]
# ---
# ## Ejercicio 6

# %% [markdown]
# Crea un array de tamaño 8x8 con valores enteros aleatorios entre 1 y 100, realiza las siguientes operaciones utilizando máscaras booleanas:
#
# * Crea una máscara que identifique los elementos mayores a 50 y reemplázalos por el valor 100.
# * Crea una máscara que identifique los elementos menores o iguales a 20 y reemplázalos por el valor -1.
# * Cuenta cuántos elementos del array son pares y cuántos son impares.
# * Crea una nueva matriz donde se reemplacen los elementos pares por su mitad y los impares por su doble.

# %%
# No está hecho.
array = np.random.rand(8, 8) * 100
array = np.round(array, 2)
print(array)
# Out:
# [[22. 27. 28. 69. 35. 16. 75. 68.]
#  [32. 74. 90. 44. 31. 41. 48. 99.]
#  [12. 52. 32. 12. 98. 38. 37. 26.]
#  [35. 93. 92.  7. 98. 82. 97. 12.]
#  [76. 66. 40. 87. 39. 28. 95. 31.]
#  [80. 12. 26. 96. 23. 88. 84. 30.]
#  [49. 79. 18. 53. 68. 83. 62. 75.]
#  [75.  1. 31. 55.  8. 25. 87. 24.]]

# %% [markdown]
# ---
# ## Ejercicio 7

# %% [markdown]
# Sin utilizar las funciones predefinidas std ni mean de NumPy, programa dichas funcionalidades mediante 2 funciones diferentes. A esas funciones le pasarás como parámetro un array y devolverán el valor calculado. Haz un prueba con un array sencillo y muestra en pantalla los resultados. El cálculo de la media es sencillo, pero para la desviación estándar tendrás que investigar un poco.

# %%
array = np.array([1, 2, 3, 4, 5, 6, 7, 8])

# Media
media = np.sum(array) / np.size(array)
print(f"Media: {media}")

# Desviación estándar
calculos = array - media
# calculos = calculos**2
# calculos = np.sum(calculos)
# Así mejor
calculos = np.sum(calculos**2)
calculos = calculos / (np.size(array))
desviacionEstandar = np.sqrt(calculos)
print(f"Desviación estándar: {desviacionEstandar}")
print(np.std(array))
# Out:
# Media: 4.5
# Desviación estándar: 2.29128784747792
# 2.29128784747792

# %% [markdown]
# ---
# ## Ejercicio 8

# %% [markdown]
# Dada una matriz, del tamaño que quieras, y con valores aleatorios entre 0 y 100; normaliza cada columna de la matriz utilizando la fórmula de normalización:
#
# ![formula](data:image/png;base64,...)
#
#
# donde:
# * X es una columna de la matriz,
# * min(𝑋) es el valor mínimo de la columna,
# * max(𝑋) es el valor máximo de la columna.

# %%
#print("De qué tamaño quieres que sea la matriz? ")
# No se puede poner inputs en Jupyter.
# tamanyo = int(input())

tamanyo = 5
array = np.random.randint(0, 100, (tamanyo, tamanyo))

for i in range(tamanyo):
    # Mi versión
    #columna = array[:, i:i+1]
    #columnaNormalizada = (columna - np.min(columna)) / (np.max(columna) - np.min(columna))
    #print(f"\nColumna normalizada {i}:")
    #print(columnaNormalizada)

    # Versión Josemi
    columna = array[:, i]
    columnaNormalizada = (columna - np.min(columna)) / (np.max(columna) - np.min(columna))
    print(columnaNormalizada)

    # Para separar
    print()
# Out:
# [0.29411765 0.         1.         0.82352941 0.66666667]
#
# [0.11764706 0.94117647 0.11764706 0.         1.        ]
#
# [0.8030303  1.         0.42424242 0.         0.63636364]
#
# [0.54761905 0.47619048 0.         1.         0.66666667]
#
# [0.         0.74193548 0.         1.         0.29032258]
